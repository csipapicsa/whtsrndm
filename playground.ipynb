# %%
import main as m

# %%
# https://osmnx.readthedocs.io/en/stable/osmnx.html?highlight=ox.graph_from_place#osmnx.graph.graph_from_place
G = m.ox.graph_from_place('Gyöngyös', network_type='drive')

# %%
Gw = m.ox.graph_from_place("Heves Vármegye", network_type="walk")
m.ox.plot_graph(Gw)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %%
import networkx as nx
# https://stackoverflow.com/questions/64846222/store-networkx-graph-object
#nx.write_gpickle(G,'myGraph.gpickle')
nx.write_gpickle()

# %%
ma = m.folium.Map(location=[47.1611615, 19.5057541], zoom_start=7, tiles='OpenStreetMap')

# %%
ma = m.ox.folium.plot_graph_folium(Gw,tiles='openstreetmap',popup_attribute='name',opacity = 0.5,color = 'red',weight= 1)

# %%
ma

# %%
#ma.save("walkpathsHeves.html")
